# %%
import json
import httplib
import pprint as pp

api_key = open('/Users/gk/Desktop/github/keys/cb', 'r').read().strip()
main_url = 'api.crunchbase.com'
site_str = '/v/1/search.js?'

def initiate_connection(url):
	return httplib.HTTPConnection(url)
	
def send_query(conn, query, filepath):
	ex_fp = open('exceptions.txt', 'w')
	count, page, outputstr = 0, 0, ""
	done = False
	while (not done):
		page += 1
		if count%500 == 0:
			print "Count: " + str(count)
		conn.request("GET", query+str(page))
		try:
			response = json.loads(conn.getresponse().read())
		except :
			ex_fp.write(json.dumps(response))
		if len(response['results']) == 0:
			done = True
			continue
		for entity in response['results']:
			if entity['namespace']=='person':
				name = "%s, %s" % (entity['last_name'], entity['first_name'])
			else :
				name = entity['name']
			try:
				count += 1
				outputstr = "\n%s\t%s\t%s" % (name, entity['permalink'],entity['namespace'])
				filepath.write(outputstr.encode('utf-8'))
			except :
				ex_fp.write(pp.pprint(response))

			

def main():
	output = 'simple_output.txt'
	fp = open(output, 'w')
	fp.write('Name\tpermalink\tnamespace')
	connection=initiate_connection(main_url)
	search_topic = "healthcare"
	query = "%squery=%s&api_key=%s&page=" % (site_str, search_topic, api_key)
	send_query (connection, query, fp)
	fp.close()

if __name__ == '__main__':
	main()
# Out:
# Count: 0
# Count: 500
# Count: 1000
# Count: 1500
# Count: 2000
# Count: 2500
# Count: 3000
# Count: 3500
# Count: 4000
# Count: 4500
# Count: 5000
# Count: 5500
# Count: 6000
# Count: 6500
# Count: 7000
# Count: 7500
# Count: 8000

# %%
import json
import httplib
import pprint as pp
import sqlite3

api_key = open('/Users/gk/Desktop/github/keys/cb', 'r').read().strip()
main_url = 'api.crunchbase.com'
site_str = '/v/1/search.js?'

def initiate_connection(url):
	return httplib.HTTPConnection(url)
	
def send_query(conn, query, sql_connection):
	ex_fp = open('exceptions.txt', 'w')
	count, page, outputstr = 0, 0, ""
	done = False
	while (not done):
		page += 1
		sql_connection.commit()
		conn.request("GET", query+str(page))
		try:
			response = json.loads(conn.getresponse().read())
		except :
			ex_fp.write(json.dumps(response))
		if len(response['results']) == 0:
			done = True
			continue
		for entity in response['results']:
			if entity['namespace']=='person':
				name = "%s, %s" % (entity['last_name'], entity['first_name'])
			else :
				name = entity['name']
			try:
				count += 1
				sql_connection.execute('''INSERT INTO recs VALUES (?, ?, ?)''', (name, entity['permalink'],entity['namespace']))
				
			except :
				ex_fp.write(pp.pprint(response))

def main():
	output = 'simple_output.txt'
	cb_connection=initiate_connection(main_url)
	search_topic = "healthcare"
	sql_connection = sqlite3.connect(search_topic+".db")
	sql_connection.cursor()
	sql_connection.execute('''DROP TABLE IF EXISTS recs''')
	sql_connection.execute('''CREATE TABLE recs (name text, permalink text, namespace text)''')
	sql_connection.commit()
	query = "%squery=%s&api_key=%s&page=" % (site_str, search_topic, api_key)
	send_query (cb_connection, query, sql_connection)
	sql_connection.close()

if __name__ == '__main__':
	main()

# %%
#connect to Entity Information endpoint
#getting data about the 'company' 'locu' 
import json
import httplib
import pprint as pp
import sqlite3

api_key = open('/Users/gk/Desktop/github/keys/cb', 'r').read().strip()
main_url = 'api.crunchbase.com'
company_entityinfo_str ='/v/1/company/'
locu_file = file('/Users/gk/Desktop/data_sci/crunchbase/locu.json', 'w')


def initiate_connection(url):
	return httplib.HTTPConnection(url)

def get_info_for_companies(connection):
    query=company_entityinfo_str+'locu.js?api_key='+api_key
    connection.request("GET",query)
    locu = connection.getresponse().read()
    locu_file.write(pp.pformat(json.loads(locu)).encode('utf-8'))
    locu_file.close()

def companies():
    cb_connection=initiate_connection(main_url)
    get_info_for_companies(cb_connection)

if __name__ == '__main__':
	companies()

# %%
#connect to entity information endpoint
#get data about apple.
import json
import httplib
import pprint as pp
import sqlite3

api_key = open('/Users/gk/Desktop/github/keys/cb', 'r').read().strip()
main_url = 'api.crunchbase.com'
company_entityinfo_str ='/v/1/company/'
apple_file = file('/Users/gk/Desktop/data_sci/crunchbase/apple.json', 'w')

def initiate_connection(url):
	return httplib.HTTPConnection(url)

def get_info_for_companies(connection):
    query=company_entityinfo_str+'apple.js?api_key='+api_key
    connection.request("GET",query)
    apple = connection.getresponse().read()
    apple_file.write(pp.pformat(json.loads(apple)).encode('utf-8'))
    apple_file.close()

def companies():
    cb_connection=initiate_connection(main_url)
    get_info_for_companies(cb_connection)

if __name__ == '__main__':
	companies()

# %%
#connect to Entity Information endpoint
#get info about zephyr-health
import json
import httplib
import pprint as pp
import sqlite3

api_key = open('/Users/gk/Desktop/github/keys/cb', 'r').read().strip()
main_url = 'api.crunchbase.com'
companies_entitylist_str = '/v/1/companies.js?'
company_entityinfo_str ='/v/1/company/'
output_file = file('/Users/gk/Desktop/data_sci/crunchbase/zephry-health.json', 'w')

def initiate_connection(url):
	return httplib.HTTPConnection(url)

def get_info_for_companies(connection):
    query=company_entityinfo_str+'zephyr-health.js?api_key='+api_key
    connection.request("GET",query)
    zephyr = connection.getresponse().read()
    output_file.write(pp.pformat(json.loads(zephyr)).encode('utf-8'))
    output_file.close()

def companies():
    cb_connection=initiate_connection(main_url)
    get_info_for_companies(cb_connection)

if __name__ == '__main__':
	companies()

# %%
#connect to companies endpoint
#getting information about every single company and filing it into companies.db
import json
import httplib
import pprint as pp
import sqlite3
import codecs

API_KEY = open('/Users/gk/Desktop/github/keys/cb', 'r').read().strip()
OUTPUTDIR='/Users/gk/Desktop/data_sci/crunchbase/data'
URL = 'api.crunchbase.com'
COMPANIES_EL = '/v/1/companies.js?'
COMPANY_EI = '/v/1/company/'
EXCEPTION_FILE= ''.join((OUTPUTDIR,'/exceptions.txt'))


def initiate_connection(url):
	return httplib.HTTPConnection(url)

def generate_description_string(company_detail):
    return '\n'.join(filter(None, [company_detail[key] for key in ['overview', 'description', 'tag_list']]))

def get_company_overview(cb_conn,permalink):
    global COMPANY_EI, API_KEY, EXCEPTION_FILE
    cb_conn.request("GET",''.join((COMPANY_EI,permalink,'.js?api_key=',API_KEY)))
    return generate_description_string(json.loads(cb_conn.getresponse().read()))

def db_vals(conn, company):
    code = lambda x: x if x != '' else None
    name = company['name']
    permalink = company['permalink']
    cat = code(company['category_code'])
    descr = get_company_overview(conn, permalink)
    return permalink, name, cat, descr
    

def send_companies_query(conn, query, sql_connection):
    global EXCEPTION_FILE
    count = 0
    conn.request("GET", query)
    val = conn.getresponse().read().replace('][',',')
    response = json.loads(val)
    for company in response:
        try :
            sql_connection.execute('''INSERT INTO companies VALUES (?, ?, ?, ?)''', db_vals(conn,company))
            count += 1
            if count % 100 == 0 :
                sql_connection.commit()
                print "Count: %d" % count
        except :
            with codecs.open(EXCEPTION_FILE, 'a') as f:
                f.write('\n')
                f.write ('=======ERROR=======\n')
                f.write(str(company))
    sql_connection.commit()

def setup_companies_table():
    global OUTPUTDIR
    sql_connection = sqlite3.connect(''.join((OUTPUTDIR,"/companies.db")))
    sql_connection.cursor()
    sql_connection.execute('''DROP TABLE IF EXISTS companies''')
    sql_connection.execute('''CREATE TABLE companies (permalink text primary key, name text, cat text, descr text)''')
    sql_connection.commit()
    return sql_connection
    
def companies():
    global URL, COMPANIES_EL, API_KEY
    cb_connection=initiate_connection(URL)
    sql_connection = setup_companies_table()
    query = "%sapi_key=%s" % (COMPANIES_EL, API_KEY)
    send_companies_query (cb_connection, query, sql_connection)
    cb_connection.close()
    sql_connection.close()

if __name__ == '__main__':
	companies()
# Out:
# Count: 100
# Count: 200
# Count: 300
# Count: 400
# Count: 500
# Count: 600
# Count: 700
# Count: 800
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-2300c1a0a7e0> in <module>()
#      74
#      75 if __name__ == '__main__':
# ---> 76         companies()
#
# <ipython-input-10-2300c1a0a7e0> in companies()
#      69     sql_connection = setup_companies_table()
#      70     query = "%sapi_key=%s" % (COMPANIES_EL, API_KEY)
# ---> 71     send_companies_query (cb_connection, query, sql_connection)
#      72     cb_connection.close()
#      73     sql_connection.close()
#
# <ipython-input-10-2300c1a0a7e0> in send_companies_query(conn, query, sql_connection)
#      52                 f.write('\n')
#      53                 f.write ('=======ERROR=======\n')
# ---> 54                 f.write(company)
#      55     sql_connection.commit()
#      56
#
# TypeError: expected a character buffer object

# %%
efgh = '{"blahdiblah":[{"a":"abcd"},{"b":1}]}'
a = json.loads(efgh)
with open('abctesting.txt', 'w') as testfile:
    for val in a['blahdiblah']:
        testfile.write(str(val))

# %%
pwd
# Out:
# u'/Users/gk/Desktop/github/data_sci/project'

# %%
#connect to companies endpoint
#getting information about every single company and filing it into companies.db
import json
import httplib
import sqlite3
import codecs
import sys

PATH = '/Users/gk/Desktop/data_sci/crunchbase'
API_KEY = open(''.join((PATH,'/keys/cb')), 'r').read().strip()
OUTPUTDIR=''.join((PATH,'/data'))
URL = 'api.crunchbase.com'
COMPANIES_EL = '/v/1/companies.js?'
COMPANY_EI = '/v/1/company/'
EXCEPTION_FILE= ''.join((OUTPUTDIR,'/exceptions.txt'))


def initiate_connection(url):
	return httplib.HTTPConnection(url)

def fetch_company_file(cb_conn, company):
    global COMPANY_EI, API_KEY, EXCEPTION_FILE, OUTPUTDIR
    query=''.join((COMPANY_EI,company['permalink'],'.js?api_key=',API_KEY))
    company_file=''.join((OUTPUTDIR,'/',company['permalink'],'.json'))
    cb_conn.request("GET",query)
    data=cb_conn.getresponse().read()
    try:
        try:
            f = open(company_file, 'r+')
            if len(f.read()) < 1:
                f.write(data)
        except :
            f = open(company_file, 'w')
            f.write(data)
        f.close()
    except:
        extype, value = sys.exc_info()[:2]
        with open(EXCEPTION_FILE, 'a') as g:
            g.write('\n=======ERROR: FETCH_COMPANY_FILE=======')
            g.write('\nTYPE: %s \t VALUE: %s' % (extype, value))
            g.write('\n'+str(company))                 

    
def fetch_companies(cb_conn, companies_file):
    global EXCEPTION_FILE
    with open(''.join((PATH,'/count.txt'))) as count_file:
        count = int(count_file.read().strip)
    with open(companies_file) as f:
        companies = json.loads(f.read(), strict=False)
        for company in companies[count:]:
            count += 1
            if count > 100:
                break
            try :
                fetch_company_file(cb_conn, company)
            except :
                extype, value = sys.exc_info()[:2]
                with open(EXCEPTION_FILE, 'a') as g:
                    g.write('\n=======ERROR: FETCH_COMPANIES=======')
                    g.write('\nTYPE: %s \t VALUE: %s' % (extype, value))
                    g.write('\n'+str(company))
        with open(''.join((PATH,'/count.txt')),'w') as count_file:
            count_file.write(str(count))

def fetch_companies_file(cb_conn):
    global COMPANIES_EL, API_KEY, OUTPUTDIR, EXCEPTION_FILE
    json_file=''.join((OUTPUTDIR,'/companies.json'))
    with open(json_file, 'r+') as f:
        if len(f.read()) < 1:
            query = ''.join((COMPANIES_EL,"api_key=",API_KEY))
            cb_conn.request("GET", query)
            try:
                f.write(cb_conn.getresponse().read().replace('][',','))
            except:
                extype, value = sys.exc_info()[:2]
                with open(EXCEPTION_FILE, 'a') as g:
                    g.write('\n=======ERROR=======')
                    g.write('\nTYPE: %s \t VALUE: %s' % (extype, value))        
    return json_file

def companies():
    global URL
    cb_connection=initiate_connection(URL)
    companies_file = fetch_companies_file(cb_connection)
    fetch_companies(cb_connection, companies_file)
    cb_connection.close()

if __name__ == '__main__':
	companies()

'''
save the contents of the initial call to a file
limit the # of calls per hour
start the exceptions file from scratch.
'''
# Out:
# '\nsave the contents of the initial call to a file\nlimit the # of calls per hour\nstart the exceptions file from scratch.\n'

# %%
import json
import httplib
import sqlite3
import codecs
import sys

PATH = '/Users/gk/Desktop/data_sci/crunchbase'
API_KEY = open(''.join((PATH,'/keys/cb')), 'r').read().strip()
OUTPUTDIR=''.join((PATH,'/data'))
URL = 'api.crunchbase.com'
COMPANIES_EL = '/v/1/companies.js?'
COMPANY_EI = '/v/1/company/'
EXCEPTION_FILE= ''.join((OUTPUTDIR,'/exceptions.txt'))

def fetch_company_file(cb_conn, company):
    global COMPANY_EI, API_KEY, EXCEPTION_FILE, OUTPUTDIR
    query=''.join((COMPANY_EI,company['permalink'],'.js?api_key=',API_KEY))
    print query
    company_file=''.join((OUTPUTDIR,'/',company['permalink'],'.json'))
    print cb_conn.__dict__
    cb_conn.request("GET",query)
    print cb_conn.__dict__
    data=cb_conn.getresponse().read()
    return data

cb_connection=initiate_connection(URL)
cf=''.join((OUTPUTDIR,'/companies.json'))
count = 0
with open(cf, 'r') as cf_file:
    companies=json.loads(cf_file.read())
    for company in companies:
        count += 1
        if count > 10: 
            break
        print fetch_company_file(cb_connection, company)
# Out:
# /v/1/company/european-tour.js?api_key=52fppsddmrwecrwejqe6hm37
# {'_buffer': [], '_HTTPConnection__state': 'Idle', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': None, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': None, '_method': None}
# {'_buffer': [], '_HTTPConnection__state': 'Request-sent', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': None, '_method': 'GET'}
# {"name": "European Tour ",
#  "permalink": "european-tour",
#  "crunchbase_url": "http://www.crunchbase.com/company/european-tour",
#  "homepage_url": null,
#  "blog_url": null,
#  "blog_feed_url": null,
#  "twitter_username": null,
#  "category_code": null,
#  "number_of_employees": null,
#  "founded_year": null,
#  "founded_month": null,
#  "founded_day": null,
#  "deadpooled_year": null,
#  "deadpooled_month": null,
#  "deadpooled_day": null,
#  "deadpooled_url": null,
#  "tag_list": null,
#  "alias_list": null,
#  "email_address": null,
#  "phone_number": null,
#  "description": null,
#  "created_at": "Mon Mar 24 18:59:42 UTC 2014",
#  "updated_at": "Mon Mar 24 18:59:42 UTC 2014",
#  "overview": null,
#  "image": null,
#  "products":
#   [],
#  "relationships":
#   [{"is_past": false,
#     "title": "Senior Consultant Advisor",
#     "person":
#      {"first_name": "John",
#       "last_name": "Farrell",
#       "permalink": "john-farrell"}}],
#  "competitions":
#   [],
#  "providerships":
#   [],
#  "total_money_raised": "$0",
#  "funding_rounds":
#   [],
#  "investments":
#   [],
#  "acquisition": null,
#  "acquisitions":
#   [],
#  "offices":
#   [],
#  "milestones":
#   [],
#  "ipo": null,
#  "video_embeds":
#   [],
#  "screenshots":
#   [],
#  "external_links":
#   [],
#  "partners":
#   []}
# /v/1/company/media-equals.js?api_key=52fppsddmrwecrwejqe6hm37
# {'_buffer': [], '_HTTPConnection__state': 'Idle', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': <httplib.HTTPResponse instance at 0x10ded4368>, '_method': 'GET'}
# {'_buffer': [], '_HTTPConnection__state': 'Request-sent', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': None, '_method': 'GET'}
# {"name": "Media Equals",
#  "permalink": "media-equals",
#  "crunchbase_url": "http://www.crunchbase.com/company/media-equals",
#  "homepage_url": null,
#  "blog_url": null,
#  "blog_feed_url": null,
#  "twitter_username": null,
#  "category_code": null,
#  "number_of_employees": null,
#  "founded_year": null,
#  "founded_month": null,
#  "founded_day": null,
#  "deadpooled_year": null,
#  "deadpooled_month": null,
#  "deadpooled_day": null,
#  "deadpooled_url": null,
#  "tag_list": null,
#  "alias_list": null,
#  "email_address": null,
#  "phone_number": null,
#  "description": null,
#  "created_at": "Mon Mar 24 18:56:25 UTC 2014",
#  "updated_at": "Mon Mar 24 18:56:25 UTC 2014",
#  "overview": null,
#  "image": null,
#  "products":
#   [],
#  "relationships":
#   [{"is_past": false,
#     "title": "Bord of Directors",
#     "person":
#      {"first_name": "John",
#       "last_name": "Farrell",
#       "permalink": "john-farrell"}}],
#  "competitions":
#   [],
#  "providerships":
#   [],
#  "total_money_raised": "$0",
#  "funding_rounds":
#   [],
#  "investments":
#   [],
#  "acquisition": null,
#  "acquisitions":
#   [],
#  "offices":
#   [],
#  "milestones":
#   [],
#  "ipo": null,
#  "video_embeds":
#   [],
#  "screenshots":
#   [],
#  "external_links":
#   [],
#  "partners":
#   []}
# /v/1/company/spotlinks.js?api_key=52fppsddmrwecrwejqe6hm37
# {'_buffer': [], '_HTTPConnection__state': 'Idle', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': <httplib.HTTPResponse instance at 0x10ded4368>, '_method': 'GET'}
# {'_buffer': [], '_HTTPConnection__state': 'Request-sent', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': None, '_method': 'GET'}
# {"name": "Spotlinks",
#  "permalink": "spotlinks",
#  "crunchbase_url": "http://www.crunchbase.com/company/spotlinks",
#  "homepage_url": "http://spotlinks.co/",
#  "blog_url": "",
#  "blog_feed_url": "",
#  "twitter_username": "Spotlinksapp",
#  "category_code": "web",
#  "number_of_employees": null,
#  "founded_year": 2013,
#  "founded_month": null,
#  "founded_day": null,
#  "deadpooled_year": null,
#  "deadpooled_month": null,
#  "deadpooled_day": null,
#  "deadpooled_url": null,
#  "tag_list": "",
#  "alias_list": "",
#  "email_address": "contact@spotlinks.co",
#  "phone_number": "",
#  "description": "",
#  "created_at": "Mon Mar 24 18:32:47 UTC 2014",
#  "updated_at": "Mon Mar 24 18:32:47 UTC 2014",
#  "overview": "\u003Cp\u003ETo date, a multitude of social networks are appearing, Spotlinks offers to their users a unique platform which gathers in one single app all the various links of these social networks.\u003C/p\u003E\n\n\u003Cp\u003EWhether you\u2019re on facebook, linkedin, twitter, foursquare, instagram etc, Spotlinks is your middleman to these connections.\u003C/p\u003E\n\n\u003Cp\u003ESpotlinks is the virtual business card that allows you to become the master of your networks.\u003C/p\u003E\n\n\u003Cp\u003EAchieve interactions, at work, a party, university, on the street, public transport, seminars and conferences\u2026 Make yourself visible at any moment, prevail and encourage curiosity.\u003C/p\u003E\n\n\u003Cp\u003EFocus and exchange your web page/ social networks/ information links, in one application.\u003C/p\u003E\n\n\u003Cp\u003EIn a few clicks add your links to your profile, spot surrounding people and start using Spotlinks.\u003C/p\u003E",
#  "image":
#   {"available_sizes":
#     [[[150,
#        150],
#       "assets/images/resized/0044/1518/441518v1-max-150x150.png"],
#      [[250,
#        250],
#       "assets/images/resized/0044/1518/441518v1-max-250x250.png"],
#      [[449,
#        449],
#       "assets/images/resized/0044/1518/441518v1-max-450x450.png"]],
#    "attribution": null},
#  "products":
#   [],
#  "relationships":
#   [],
#  "competitions":
#   [],
#  "providerships":
#   [],
#  "total_money_raised": "$0",
#  "funding_rounds":
#   [],
#  "investments":
#   [],
#  "acquisition": null,
#  "acquisitions":
#   [],
#  "offices":
#   [],
#  "milestones":
#   [],
#  "ipo": null,
#  "video_embeds":
#   [],
#  "screenshots":
#   [{"available_sizes":
#      [[[150,
#         84],
#        "assets/images/resized/0044/1517/441517v1-max-150x150.png"],
#       [[250,
#         141],
#        "assets/images/resized/0044/1517/441517v1-max-250x250.png"],
#       [[450,
#         254],
#        "assets/images/resized/0044/1517/441517v1-max-450x450.png"]],
#     "attribution": null}],
#  "external_links":
#   [{"external_url": "https://www.facebook.com/spotlinksapp",
#     "title": "Spotlinks"}],
#  "partners":
#   []}
# /v/1/company/mexican-subsidiary.js?api_key=52fppsddmrwecrwejqe6hm37
# {'_buffer': [], '_HTTPConnection__state': 'Idle', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': <httplib.HTTPResponse instance at 0x10ded4368>, '_method': 'GET'}
# {'_buffer': [], '_HTTPConnection__state': 'Request-sent', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': None, '_method': 'GET'}
# {"name": "Mexican subsidiary ",
#  "permalink": "mexican-subsidiary",
#  "crunchbase_url": "http://www.crunchbase.com/company/mexican-subsidiary",
#  "homepage_url": null,
#  "blog_url": null,
#  "blog_feed_url": null,
#  "twitter_username": null,
#  "category_code": null,
#  "number_of_employees": null,
#  "founded_year": null,
#  "founded_month": null,
#  "founded_day": null,
#  "deadpooled_year": null,
#  "deadpooled_month": null,
#  "deadpooled_day": null,
#  "deadpooled_url": null,
#  "tag_list": null,
#  "alias_list": null,
#  "email_address": null,
#  "phone_number": null,
#  "description": null,
#  "created_at": "Mon Mar 24 18:19:32 UTC 2014",
#  "updated_at": "Mon Mar 24 18:19:32 UTC 2014",
#  "overview": null,
#  "image": null,
#  "products":
#   [],
#  "relationships":
#   [{"is_past": false,
#     "title": "Chairman of the Board \u0026 Executive President",
#     "person":
#      {"first_name": "Pablo",
#       "last_name": "Lagos Espinosa",
#       "permalink": "pablo-lagos-espinosa"}}],
#  "competitions":
#   [],
#  "providerships":
#   [],
#  "total_money_raised": "$0",
#  "funding_rounds":
#   [],
#  "investments":
#   [],
#  "acquisition": null,
#  "acquisitions":
#   [],
#  "offices":
#   [],
#  "milestones":
#   [],
#  "ipo": null,
#  "video_embeds":
#   [],
#  "screenshots":
#   [],
#  "external_links":
#   [],
#  "partners":
#   []}
# /v/1/company/jivebike.js?api_key=52fppsddmrwecrwejqe6hm37
# {'_buffer': [], '_HTTPConnection__state': 'Idle', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': <httplib.HTTPResponse instance at 0x10ded4368>, '_method': 'GET'}
# {'_buffer': [], '_HTTPConnection__state': 'Request-sent', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': None, '_method': 'GET'}
# {"name": "JiveBike",
#  "permalink": "jivebike",
#  "crunchbase_url": "http://www.crunchbase.com/company/jivebike",
#  "homepage_url": "https://jivebike.com/jive-bike/",
#  "blog_url": "http://getjive.tumblr.com/",
#  "blog_feed_url": "",
#  "twitter_username": "jivebike",
#  "category_code": "transportation",
#  "number_of_employees": null,
#  "founded_year": null,
#  "founded_month": null,
#  "founded_day": null,
#  "deadpooled_year": null,
#  "deadpooled_month": null,
#  "deadpooled_day": null,
#  "deadpooled_url": null,
#  "tag_list": "bike, bicycle",
#  "alias_list": "",
#  "email_address": "marcin@jivebike.com",
#  "phone_number": "",
#  "description": "Folding electric bicycle",
#  "created_at": "Mon Mar 24 18:12:36 UTC 2014",
#  "updated_at": "Mon Mar 24 18:14:59 UTC 2014",
#  "overview": "\u003Cp\u003EJIVE Bike started as a research project at UCL in late 2011. After months of exploring the possibilities of creating a vehicle that would address the needs of today\u2019s cosmopolitans who commute across big cities, the team concluded that only chainless, electric bicycle \u0026#8216;ticks all the boxes.\u0026#8217;\u003C/p\u003E\n\n\u003Cp\u003EWith significant financial and business support from University College London, JIVE Bike grew from project into commercial enterprise in April 2012. Since then, JIVE Bike has won product and business awards proving the validity of concept and market, including Crowdcube\u2019s Best Product Award, London Entrepreneurs\u2019 Challenge 2011 and many others.\u003C/p\u003E\n\n\u003Cp\u003EAfter constructing functional prototypes, JIVE Bike has moved into the current stage of project which is setting up manufacturing facilities in the Founder\u2019s home town: Mielec, Poland.\u003C/p\u003E",
#  "image":
#   {"available_sizes":
#     [[[67,
#        46],
#       "assets/images/resized/0044/1505/441505v1-max-150x150.png"],
#      [[67,
#        46],
#       "assets/images/resized/0044/1505/441505v1-max-250x250.png"],
#      [[67,
#        46],
#       "assets/images/resized/0044/1505/441505v1-max-450x450.png"]],
#    "attribution": null},
#  "products":
#   [],
#  "relationships":
#   [],
#  "competitions":
#   [],
#  "providerships":
#   [],
#  "total_money_raised": "$0",
#  "funding_rounds":
#   [],
#  "investments":
#   [],
#  "acquisition": null,
#  "acquisitions":
#   [],
#  "offices":
#   [{"description": "Gordon House",
#     "address1": "29 Gordon Square",
#     "address2": "WC1H 0PP",
#     "zip_code": "",
#     "city": "London",
#     "state_code": null,
#     "country_code": "GBR",
#     "latitude": null,
#     "longitude": null}],
#  "milestones":
#   [],
#  "ipo": null,
#  "video_embeds":
#   [],
#  "screenshots":
#   [{"available_sizes":
#      [[[150,
#         83],
#        "assets/images/resized/0044/1508/441508v1-max-150x150.png"],
#       [[250,
#         139],
#        "assets/images/resized/0044/1508/441508v1-max-250x250.png"],
#       [[450,
#         250],
#        "assets/images/resized/0044/1508/441508v1-max-450x450.png"]],
#     "attribution": null}],
#  "external_links":
#   [{"external_url": "https://www.facebook.com/jivebike",
#     "title": "JiveBike"}],
#  "partners":
#   []}
# /v/1/company/2dialog.js?api_key=52fppsddmrwecrwejqe6hm37
# {'_buffer': [], '_HTTPConnection__state': 'Idle', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': <httplib.HTTPResponse instance at 0x10ded4368>, '_method': 'GET'}
# {'_buffer': [], '_HTTPConnection__state': 'Request-sent', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': None, '_method': 'GET'}
# {"name": "2Dialog",
#  "permalink": "2dialog",
#  "crunchbase_url": "http://www.crunchbase.com/company/2dialog",
#  "homepage_url": null,
#  "blog_url": null,
#  "blog_feed_url": null,
#  "twitter_username": null,
#  "category_code": null,
#  "number_of_employees": null,
#  "founded_year": null,
#  "founded_month": null,
#  "founded_day": null,
#  "deadpooled_year": null,
#  "deadpooled_month": null,
#  "deadpooled_day": null,
#  "deadpooled_url": null,
#  "tag_list": null,
#  "alias_list": null,
#  "email_address": null,
#  "phone_number": null,
#  "description": null,
#  "created_at": "Mon Mar 24 18:12:12 UTC 2014",
#  "updated_at": "Mon Mar 24 18:12:12 UTC 2014",
#  "overview": null,
#  "image": null,
#  "products":
#   [],
#  "relationships":
#   [{"is_past": true,
#     "title": "",
#     "person":
#      {"first_name": "Harry",
#       "last_name": "King",
#       "permalink": "harry-king"}}],
#  "competitions":
#   [],
#  "providerships":
#   [],
#  "total_money_raised": "$0",
#  "funding_rounds":
#   [],
#  "investments":
#   [],
#  "acquisition": null,
#  "acquisitions":
#   [],
#  "offices":
#   [],
#  "milestones":
#   [],
#  "ipo": null,
#  "video_embeds":
#   [],
#  "screenshots":
#   [],
#  "external_links":
#   [],
#  "partners":
#   []}
# /v/1/company/sui-generis-solutions.js?api_key=52fppsddmrwecrwejqe6hm37
# {'_buffer': [], '_HTTPConnection__state': 'Idle', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': <httplib.HTTPResponse instance at 0x10ded4368>, '_method': 'GET'}
# {'_buffer': [], '_HTTPConnection__state': 'Request-sent', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': None, '_method': 'GET'}
# {"name": "Sui Generis Solutions",
#  "permalink": "sui-generis-solutions",
#  "crunchbase_url": "http://www.crunchbase.com/company/sui-generis-solutions",
#  "homepage_url": null,
#  "blog_url": null,
#  "blog_feed_url": null,
#  "twitter_username": null,
#  "category_code": null,
#  "number_of_employees": null,
#  "founded_year": null,
#  "founded_month": null,
#  "founded_day": null,
#  "deadpooled_year": null,
#  "deadpooled_month": null,
#  "deadpooled_day": null,
#  "deadpooled_url": null,
#  "tag_list": null,
#  "alias_list": null,
#  "email_address": null,
#  "phone_number": null,
#  "description": null,
#  "created_at": "Mon Mar 24 18:12:11 UTC 2014",
#  "updated_at": "Mon Mar 24 18:12:11 UTC 2014",
#  "overview": null,
#  "image": null,
#  "products":
#   [],
#  "relationships":
#   [{"is_past": true,
#     "title": "",
#     "person":
#      {"first_name": "Harry",
#       "last_name": "King",
#       "permalink": "harry-king"}}],
#  "competitions":
#   [],
#  "providerships":
#   [],
#  "total_money_raised": "$0",
#  "funding_rounds":
#   [],
#  "investments":
#   [],
#  "acquisition": null,
#  "acquisitions":
#   [],
#  "offices":
#   [],
#  "milestones":
#   [],
#  "ipo": null,
#  "video_embeds":
#   [],
#  "screenshots":
#   [],
#  "external_links":
#   [],
#  "partners":
#   []}
# /v/1/company/eskom.js?api_key=52fppsddmrwecrwejqe6hm37
# {'_buffer': [], '_HTTPConnection__state': 'Idle', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': <httplib.HTTPResponse instance at 0x10ded4368>, '_method': 'GET'}
# {'_buffer': [], '_HTTPConnection__state': 'Request-sent', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': None, '_method': 'GET'}
# {"name": "Eskom",
#  "permalink": "eskom",
#  "crunchbase_url": "http://www.crunchbase.com/company/eskom",
#  "homepage_url": null,
#  "blog_url": null,
#  "blog_feed_url": null,
#  "twitter_username": null,
#  "category_code": null,
#  "number_of_employees": null,
#  "founded_year": null,
#  "founded_month": null,
#  "founded_day": null,
#  "deadpooled_year": null,
#  "deadpooled_month": null,
#  "deadpooled_day": null,
#  "deadpooled_url": null,
#  "tag_list": null,
#  "alias_list": null,
#  "email_address": null,
#  "phone_number": null,
#  "description": null,
#  "created_at": "Mon Mar 24 18:12:10 UTC 2014",
#  "updated_at": "Mon Mar 24 18:12:10 UTC 2014",
#  "overview": null,
#  "image": null,
#  "products":
#   [],
#  "relationships":
#   [{"is_past": true,
#     "title": "",
#     "person":
#      {"first_name": "Harry",
#       "last_name": "King",
#       "permalink": "harry-king"}}],
#  "competitions":
#   [],
#  "providerships":
#   [],
#  "total_money_raised": "$0",
#  "funding_rounds":
#   [],
#  "investments":
#   [],
#  "acquisition": null,
#  "acquisitions":
#   [],
#  "offices":
#   [],
#  "milestones":
#   [],
#  "ipo": null,
#  "video_embeds":
#   [],
#  "screenshots":
#   [],
#  "external_links":
#   [],
#  "partners":
#   []}
# /v/1/company/gbatteries.js?api_key=52fppsddmrwecrwejqe6hm37
# {'_buffer': [], '_HTTPConnection__state': 'Idle', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': <httplib.HTTPResponse instance at 0x10ded4368>, '_method': 'GET'}
# {'_buffer': [], '_HTTPConnection__state': 'Request-sent', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': None, '_method': 'GET'}
# {"name": "Gbatteries",
#  "permalink": "gbatteries",
#  "crunchbase_url": "http://www.crunchbase.com/company/gbatteries",
#  "homepage_url": "http://www.gbatteries.com/",
#  "blog_url": "",
#  "blog_feed_url": "",
#  "twitter_username": "",
#  "category_code": "hardware",
#  "number_of_employees": null,
#  "founded_year": null,
#  "founded_month": null,
#  "founded_day": null,
#  "deadpooled_year": null,
#  "deadpooled_month": null,
#  "deadpooled_day": null,
#  "deadpooled_url": null,
#  "tag_list": "",
#  "alias_list": "",
#  "email_address": "",
#  "phone_number": "",
#  "description": "Portable backup battery",
#  "created_at": "Mon Mar 24 17:24:38 UTC 2014",
#  "updated_at": "Mon Mar 24 17:35:33 UTC 2014",
#  "overview": "\u003Cp\u003EA battery management system (BMS) that increases battery capacity and cycle count.\u003C/p\u003E\n\n\u003Cp\u003EBatteryOS is a new way of controlling rechargeable lithium-ion batteries that enables any normal battery to have higher capacity and not degrade over time.\u003C/p\u003E",
#  "image":
#   {"available_sizes":
#     [[[150,
#        40],
#       "assets/images/resized/0044/1489/441489v1-max-150x150.png"],
#      [[205,
#        56],
#       "assets/images/resized/0044/1489/441489v1-max-250x250.png"],
#      [[205,
#        56],
#       "assets/images/resized/0044/1489/441489v1-max-450x450.png"]],
#    "attribution": null},
#  "products":
#   [],
#  "relationships":
#   [],
#  "competitions":
#   [],
#  "providerships":
#   [],
#  "total_money_raised": "$0",
#  "funding_rounds":
#   [],
#  "investments":
#   [],
#  "acquisition": null,
#  "acquisitions":
#   [],
#  "offices":
#   [],
#  "milestones":
#   [],
#  "ipo": null,
#  "video_embeds":
#   [{"embed_code": "\u003Ciframe width=\"430\" height=\"315\" src=\"//www.youtube.com/embed/Xgc_B3r-2g8\" frameborder=\"0\" allowfullscreen\u003E\u003C/iframe\u003E",
#     "description": "\u003Cp\u003EBatteryBox\u003C/p\u003E"}],
#  "screenshots":
#   [{"available_sizes":
#      [[[150,
#         85],
#        "assets/images/resized/0044/1488/441488v1-max-150x150.png"],
#       [[250,
#         141],
#        "assets/images/resized/0044/1488/441488v1-max-250x250.png"],
#       [[450,
#         255],
#        "assets/images/resized/0044/1488/441488v1-max-450x450.png"]],
#     "attribution": null}],
#  "external_links":
#   [],
#  "partners":
#   []}
# /v/1/company/american-institute-of-medical-biological-engineering.js?api_key=52fppsddmrwecrwejqe6hm37
# {'_buffer': [], '_HTTPConnection__state': 'Idle', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': <httplib.HTTPResponse instance at 0x10ded4368>, '_method': 'GET'}
# {'_buffer': [], '_HTTPConnection__state': 'Request-sent', '_tunnel_headers': {}, '_tunnel_host': None, 'sock': <socket._socketobject object at 0x1045b4d00>, 'port': 80, 'host': 'api.crunchbase.com', '_tunnel_port': None, 'timeout': <object object at 0x1002b74f0>, 'source_address': None, '_HTTPConnection__response': None, '_method': 'GET'}
# {"name": "American  Institute of Medical \u0026 Biological Engineering",
#  "permalink": "american-institute-of-medical-biological-engineering",
#  "crunchbase_url": "http://www.crunchbase.com/company/american-institute-of-medical-biological-engineering",
#  "homepage_url": null,
#  "blog_url": null,
#  "blog_feed_url": null,
#  "twitter_username": null,
#  "category_code": null,
#  "number_of_employees": null,
#  "founded_year": null,
#  "founded_month": null,
#  "founded_day": null,
#  "deadpooled_year": null,
#  "deadpooled_month": null,
#  "deadpooled_day": null,
#  "deadpooled_url": null,
#  "tag_list": null,
#  "alias_list": null,
#  "email_address": null,
#  "phone_number": null,
#  "description": null,
#  "created_at": "Mon Mar 24 17:05:46 UTC 2014",
#  "updated_at": "Mon Mar 24 17:05:46 UTC 2014",
#  "overview": null,
#  "image": null,
#  "products":
#   [],
#  "relationships":
#   [{"is_past": true,
#     "title": "",
#     "person":
#      {"first_name": "John",
#       "last_name": "Chae",
#       "permalink": "john-chae"}}],
#  "competitions":
#   [],
#  "providerships":
#   [],
#  "total_money_raised": "$0",
#  "funding_rounds":
#   [],
#  "investments":
#   [],
#  "acquisition": null,
#  "acquisitions":
#   [],
#  "offices":
#   [],
#  "milestones":
#   [],
#  "ipo": null,
#  "video_embeds":
#   [],
#  "screenshots":
#   [],
#  "external_links":
#   [],
#  "partners":
#   []}

# %%
for i in [(1,0),(2,0),(3,0),(3,1),(4,2),(6,3)]:
    try : 
        print(i[0]/i[1])
    except :
        print "Dividing by zero!"
    finally :
        print "Done!"
# Out:
# Dividing by zero!
# Done!
# Dividing by zero!
# Done!
# Dividing by zero!
# Done!
# 3
# Done!
# 2
# Done!
# 2
# Done!
