# %%
import json
import httplib
import pprint as pp

api_key = '52fppsddmrwecrwejqe6hm37'
main_url = 'api.crunchbase.com'
site_str = '/v/1/search.js?'


def initiate_connection(url):
	return httplib.HTTPConnection(url)
	
def send_query(conn, query, filepath):
	ex_fp = open('exceptions.txt', 'w')
	count, page, outputstr = 0, 0, ""
	done = False
	while (not done):
		page += 1
		if count%500 == 0:
			print "Count: " + str(count)
		conn.request("GET", query+str(page))
		try:
			response = json.loads(conn.getresponse().read())
		except :
			ex_fp.write(json.dumps(response))
		if len(response['results']) == 0:
			done = True
			continue
		for entity in response['results']:
			if entity['namespace']=='person':
				name = "%s, %s" % (entity['last_name'], entity['first_name'])
			else :
				name = entity['name']
			try:
				count += 1
				outputstr = "\n%s\t%s\t%s" % (name, entity['permalink'],entity['namespace'])
				filepath.write(outputstr.encode('utf-8'))
			except :
				ex_fp.write(pp.pprint(response))

			

def main():
	output = 'simple_output.txt'
	fp = open(output, 'w')
	fp.write('Name\tpermalink\tnamespace')
	connection=initiate_connection(main_url)
	search_topic = "healthcare"
	query = "%squery=%s&api_key=%s&page=" % (site_str, search_topic, api_key)
	send_query (connection, query, fp)
	fp.close()

if __name__ == '__main__':
	main()
# Out:
# Count: 0
# Count: 500
# Count: 1000
# Count: 1500
# Count: 2000
# Count: 2500
# Count: 3000
# Count: 3500
# Count: 4000
# Count: 4500
# Count: 5000
# Count: 5500
# Count: 6000
# Count: 6500
# Count: 7000
# Count: 7500

# %%
import json
import httplib
import pprint as pp
import sqlite3

api_key = '52fppsddmrwecrwejqe6hm37'
main_url = 'api.crunchbase.com'
site_str = '/v/1/search.js?'


def initiate_connection(url):
	return httplib.HTTPConnection(url)
	
def send_query(conn, query, sql_connection):
	ex_fp = open('exceptions.txt', 'w')
	count, page, outputstr = 0, 0, ""
	done = False
	while (not done):
		page += 1
		sql_connection.commit()
		conn.request("GET", query+str(page))
		try:
			response = json.loads(conn.getresponse().read())
		except :
			ex_fp.write(json.dumps(response))
		if len(response['results']) == 0:
			done = True
			continue
		for entity in response['results']:
			if entity['namespace']=='person':
				name = "%s, %s" % (entity['last_name'], entity['first_name'])
			else :
				name = entity['name']
			try:
				count += 1
				sql_connection.execute('''INSERT INTO recs VALUES (?, ?, ?)''', (name, entity['permalink'],entity['namespace']))
				
			except :
				ex_fp.write(pp.pprint(response))

			

def main():
	output = 'simple_output.txt'
	cb_connection=initiate_connection(main_url)
	search_topic = "healthcare"
	sql_connection = sqlite3.connect(search_topic+".db")
	sql_connection.cursor()
	sql_connection.execute('''DROP TABLE IF EXISTS recs''')
	sql_connection.execute('''CREATE TABLE recs (name text, permalink text, namespace text)''')
	sql_connection.commit()
	query = "%squery=%s&api_key=%s&page=" % (site_str, search_topic, api_key)
	send_query (cb_connection, query, sql_connection)
	sql_connection.close()

if __name__ == '__main__':
	main()

# %%
#connect to companies endpoint
import json
import httplib
import pprint as pp
import sqlite3

api_key = '52fppsddmrwecrwejqe6hm37'
main_url = 'api.crunchbase.com'
companies_entitylist_str = '/v/1/companies.js?'
company_entityinfo_str ='/v/1/company/'

def initiate_connection(url):
	return httplib.HTTPConnection(url)
	
def send_companies_query(conn, query, sql_connection):
    ex_fp = open('exceptions.txt', 'w')
    conn.request("GET", query)
    try:
        val = conn.getresponse().read().replace('][',',')
        response = json.loads(val)
        for company in response:
            try:
                sql_connection.execute('''INSERT INTO companies VALUES (?, ?, ?)''', (company['name'], company['permalink'],company['category_code']))
            except :
                ex_fp.write(json.dumps(response))
    except ValueError, e:
        ex_fp.write(val)
    ex_fp.close()
    sql_connection.commit()

def get_info_for_companies(connection):
    query=company_entityinfo_str+'locu.js?api_key='+api_key
    connection.request("GET",query)
    apple = connection.getresponse().read()
    print (pp.pprint(json.loads(apple)))

def companies():
	#output = 'simple_output.txt'
    cb_connection=initiate_connection(main_url)
    get_info_for_companies(cb_connection)
    #sql_connection = sqlite3.connect("companies.db")
    #sql_connection.cursor()
    #sql_connection.execute('''DROP TABLE IF EXISTS companies''')
    #sql_connection.execute('''CREATE TABLE companies (name text, permalink text, categorycode text)''')
    #sql_connection.commit()
    #query = "%sapi_key=%s" % (companies_entitylist_str, api_key)
    #send_companies_query (cb_connection, query, sql_connection)
    #sql_connection.close(cb_connection)

if __name__ == '__main__':
	companies()
# Out:
# {u'acquisition': {u'acquired_day': 19,
#                   u'acquired_month': 8,
#                   u'acquired_year': 2013,
#                   u'acquiring_company': {u'name': u'GoDaddy',
#                                          u'permalink': u'godaddy'},
#                   u'price_amount': 70000000.0,
#                   u'price_currency_code': u'USD',
#                   u'source_description': u'GoDaddy Acquires Local Business Data Provider Locu',
#                   u'source_url': u'http://techcrunch.com/2013/08/19/godaddy-acquires-local-business-data-provider-locu/',
#                   u'term_code': u'cash_and_stock'},
#  u'acquisitions': [],
#  u'alias_list': u'MenuPlatform',
#  u'blog_feed_url': u'',
#  u'blog_url': u'http://blog.locu.com',
#  u'category_code': u'advertising',
#  u'competitions': [{u'competitor': {u'name': u'SinglePlatform',
#                                     u'permalink': u'singleplatform'}},
#                    {u'competitor': {u'name': u'GrubHub',
#                                     u'permalink': u'grubhub'}},
#                    {u'competitor': {u'name': u'Delivery.com',
#                                     u'permalink': u'delivery-com'}}],
#  u'created_at': u'Thu Sep 01 16:02:32 UTC 2011',
#  u'crunchbase_url': u'http://www.crunchbase.com/company/locu',
#  u'deadpooled_day': None,
#  u'deadpooled_month': None,
#  u'deadpooled_url': None,
#  u'deadpooled_year': None,
#  u'description': u'',
#  u'email_address': u'',
#  u'external_links': [{u'external_url': u'http://www.boston.com/business/technology/innoeco/2011/09/the_tabletech_rundown_boston_s.html',
#                       u'title': u'Boston Globe | The TableTech rundown: Boston start-ups trying to upgrade the restaurant experience'},
#                      {u'external_url': u'http://www.xconomy.com/boston/2011/09/07/locu-formerly-goodplates-raises-seed-funding-to-pursue-online-menu-platform/',
#                       u'title': u'Xconomy | Locu, Formerly Goodplates, Raises Seed Funding to Pursue Online Menu Platform'},
#                      {u'external_url': u'http://www.huffingtonpost.com/2011/10/27/locu-local-search_n_1019173.html',
#                       u'title': u"Huffington Post | Locu Looks To Provide The 'Missing Piece' In Local Search"}],
#  u'founded_day': None,
#  u'founded_month': None,
#  u'founded_year': 2011,
#  u'funding_rounds': [{u'funded_day': 7,
#                       u'funded_month': 9,
#                       u'funded_year': 2011,
#                       u'id': 25227,
#                       u'investments': [{u'company': None,
#                                         u'financial_org': None,
#                                         u'person': {u'first_name': u'Gil',
#                                                     u'last_name': u'Elbaz',
#                                                     u'permalink': u'gil-elbaz'}},
#                                        {u'company': None,
#                                         u'financial_org': None,
#                                         u'person': {u'first_name': u'Bruno',
#                                                     u'last_name': u'Bowden',
#                                                     u'permalink': u'bruno-bowden'}},
#                                        {u'company': None,
#                                         u'financial_org': None,
#                                         u'person': {u'first_name': u'Jeff',
#                                                     u'last_name': u'Hammerbacher',
#                                                     u'permalink': u'jeff-hammerbacher'}},
#                                        {u'company': None,
#                                         u'financial_org': None,
#                                         u'person': {u'first_name': u'Dharmesh',
#                                                     u'last_name': u'Shah',
#                                                     u'permalink': u'dharmesh-shah'}},
#                                        {u'company': None,
#                                         u'financial_org': None,
#                                         u'person': {u'first_name': u'Michael',
#                                                     u'last_name': u'Abbott',
#                                                     u'permalink': u'michael-abbott'}},
#                                        {u'company': None,
#                                         u'financial_org': None,
#                                         u'person': {u'first_name': u'Andrew',
#                                                     u'last_name': u'McCollum',
#                                                     u'permalink': u'andrew-mccollum'}},
#                                        {u'company': None,
#                                         u'financial_org': None,
#                                         u'person': {u'first_name': u'Ed',
#                                                     u'last_name': u'Roberts',
#                                                     u'permalink': u'ed-roberts'}},
#                                        {u'company': None,
#                                         u'financial_org': None,
#                                         u'person': {u'first_name': u'Jean',
#                                                     u'last_name': u'Hammond',
#                                                     u'permalink': u'jean-hammond'}},
#                                        {u'company': None,
#                                         u'financial_org': None,
#                                         u'person': {u'first_name': u'Matt',
#                                                     u'last_name': u'Ocko',
#                                                     u'permalink': u'matt-ocko'}},
#                                        {u'company': None,
#                                         u'financial_org': {u'name': u'Quotidian Ventures',
#                                                            u'permalink': u'quotidian-ventures'},
#                                         u'person': None}],
#                       u'raised_amount': 600000.0,
#                       u'raised_currency_code': u'USD',
#                       u'round_code': u'seed',
#                       u'source_description': u'Local Business Data Provider Locu Raises Seed Round',
#                       u'source_url': u'http://techcrunch.com/2011/09/07/local-business-data-provider-locu-raises-seed-round/'},
#                      {u'funded_day': 23,
#                       u'funded_month': 4,
#                       u'funded_year': 2012,
#                       u'id': 29484,
#                       u'investments': [{u'company': None,
#                                         u'financial_org': {u'name': u'General Catalyst Partners',
#                                                            u'permalink': u'general-catalyst-partners'},
#                                         u'person': None},
#                                        {u'company': None,
#                                         u'financial_org': {u'name': u'Lowercase Capital',
#                                                            u'permalink': u'lowercase-capital'},
#                                         u'person': None},
#                                        {u'company': None,
#                                         u'financial_org': {u'name': u'Lightbank',
#                                                            u'permalink': u'lightbank'},
#                                         u'person': None},
#                                        {u'company': None,
#                                         u'financial_org': {u'name': u'SV Angel',
#                                                            u'permalink': u'sv-angel'},
#                                         u'person': None},
#                                        {u'company': None,
#                                         u'financial_org': None,
#                                         u'person': {u'first_name': u'Naval',
#                                                     u'last_name': u'Ravikant',
#                                                     u'permalink': u'naval-ravikant'}},
#                                        {u'company': None,
#                                         u'financial_org': None,
#                                         u'person': {u'first_name': u'Babak',
#                                                     u'last_name': u'Nivi',
#                                                     u'permalink': u'babak-nivi'}},
#                                        {u'company': None,
#                                         u'financial_org': {u'name': u'Quotidian Ventures',
#                                                            u'permalink': u'quotidian-ventures'},
#                                         u'person': None},
#                                        {u'company': None,
#                                         u'financial_org': None,
#                                         u'person': {u'first_name': u'Matt',
#                                                     u'last_name': u'Ocko',
#                                                     u'permalink': u'matt-ocko'}}],
#                       u'raised_amount': 4000000.0,
#                       u'raised_currency_code': u'USD',
#                       u'round_code': u'a',
#                       u'source_description': u'Data-Focused Locu Raises $4M Series A From General Catalyst, Lowercase, Lightbank & SV Angel',
#                       u'source_url': u'http://techcrunch.com/2012/04/23/data-focused-locu-raises-4m-series-a-from-general-catalyst-lowercase-lightbank-sv-angel/'}],
#  u'homepage_url': u'http://locu.com',
#  u'image': {u'attribution': None,
#             u'available_sizes': [[[150, 112],
#                                   u'assets/images/resized/0015/2241/152241v8-max-150x150.png'],
#                                  [[250, 187],
#                                   u'assets/images/resized/0015/2241/152241v8-max-250x250.png'],
#                                  [[450, 337],
#                                   u'assets/images/resized/0015/2241/152241v8-max-450x450.png']]},
#  u'investments': [],
#  u'ipo': None,
#  u'milestones': [],
#  u'name': u'Locu',
#  u'number_of_employees': None,
#  u'offices': [{u'address1': u'100 Main',
#                u'address2': u'',
#                u'city': u'Cambridge',
#                u'country_code': u'USA',
#                u'description': u'Dogpatch Labs',
#                u'latitude': None,
#                u'longitude': None,
#                u'state_code': u'MA',
#                u'zip_code': u'02142'},
#               {u'address1': u'560 Sutter Street, Suite 300',
#                u'address2': u'',
#                u'city': u'San Francisco',
#                u'country_code': u'USA',
#                u'description': u'',
#                u'latitude': None,
#                u'longitude': None,
#                u'state_code': u'CA',
#                u'zip_code': u'94102'}],
#  u'overview': u'<p>Locu helps local businesses be found. When businesses add their street address, phone number, hours of operation, and menus / service lists to Locu, Locu gets them on the map in front of over 200 million potential customers online.  Instead of having to use multiple sites to manage their business listings and showcase their products and services, businesses can update just once with Locu, and Locu will publish changes in real-time to their web and mobile sites as well as to partner sites including Yelp, Foursquare, OpenTable, YP, TripAdvisor and Facebook.</p>\n\n<p>Over 30,000 businesses including restaurants, spas, salons, accountants, photographers, and home remodeling companies are using Locu to promote their businesses online.</p>\n\n<p>Locu was founded by MIT graduates and is backed by investors including General Catalyst Capital Partners, Lowercase, Lightbank, and SV Angel.</p>',
#  u'partners': [],
#  u'permalink': u'locu',
#  u'phone_number': u'(415) 484-8819',
#  u'products': [],
#  u'providerships': [{u'is_past': False,
#                      u'provider': {u'name': u'Sunstein Kann Murphy & Timbers',
#                                    u'permalink': u'sunstein-kann-murphy-timbers'},
#                      u'title': u'IP'},
#                     {u'is_past': False,
#                      u'provider': {u'name': u'SVB', u'permalink': u'svb'},
#                      u'title': u'Banking'}],
#  u'relationships': [{u'is_past': False,
#                      u'person': {u'first_name': u'Rene',
#                                  u'last_name': u'Reinsberg',
#                                  u'permalink': u'rene-reinsberg'},
#                      u'title': u'CEO'},
#                     {u'is_past': False,
#                      u'person': {u'first_name': u'Marek',
#                                  u'last_name': u'Olszewski',
#                                  u'permalink': u'marek-olszewski'},
#                      u'title': u'CTO'},
#                     {u'is_past': False,
#                      u'person': {u'first_name': u'Marc',
#                                  u'last_name': u'Piette',
#                                  u'permalink': u'marc-piette'},
#                      u'title': u'COO'},
#                     {u'is_past': False,
#                      u'person': {u'first_name': u'Michael',
#                                  u'last_name': u'Abbott',
#                                  u'permalink': u'michael-abbott'},
#                      u'title': u'Seed Investor'},
#                     {u'is_past': True,
#                      u'person': {u'first_name': u'Fresh',
#                                  u'last_name': u'Pond Partners',
#                                  u'permalink': u'fresh-pond-partners'},
#                      u'title': u''}],
#  u'screenshots': [{u'attribution': None,
#                    u'available_sizes': [[[150, 93],
#                                          u'assets/images/resized/0024/1709/241709v2-max-150x150.jpg'],
#                                         [[250, 156],
#                                          u'assets/images/resized/0024/1709/241709v2-max-250x250.jpg'],
#                                         [[450, 281],
#                                          u'assets/images/resized/0024/1709/241709v2-max-450x450.jpg']]},
#                   {u'attribution': None,
#                    u'available_sizes': [[[134, 150],
#                                          u'assets/images/resized/0030/2177/302177v2-max-150x150.png'],
#                                         [[223, 250],
#                                          u'assets/images/resized/0030/2177/302177v2-max-250x250.png'],
#                                         [[402, 450],
#                                          u'assets/images/resized/0030/2177/302177v2-max-450x450.png']]},
#                   {u'attribution': None,
#                    u'available_sizes': [[[129, 150],
#                                          u'assets/images/resized/0030/2178/302178v2-max-150x150.png'],
#                                         [[216, 250],
#                                          u'assets/images/resized/0030/2178/302178v2-max-250x250.png'],
#                                         [[389, 450],
#                                          u'assets/images/resized/0030/2178/302178v2-max-450x450.png']]},
#                   {u'attribution': None,
#                    u'available_sizes': [[[130, 150],
#                                          u'assets/images/resized/0030/2180/302180v2-max-150x150.png'],
#                                         [[217, 250],
#                                          u'assets/images/resized/0030/2180/302180v2-max-250x250.png'],
#                                         [[391, 450],
#                                          u'assets/images/resized/0030/2180/302180v2-max-450x450.png']]},
#                   {u'attribution': None,
#                    u'available_sizes': [[[150, 133],
#                                          u'assets/images/resized/0031/5228/315228v2-max-150x150.png'],
#                                         [[250, 222],
#                                          u'assets/images/resized/0031/5228/315228v2-max-250x250.png'],
#                                         [[450, 400],
#                                          u'assets/images/resized/0031/5228/315228v2-max-450x450.png']]}],
#  u'tag_list': u'structured-data, database, local-search, content, hyperlocal, api, menu-data, menu-api, menu, restaurant',
#  u'total_money_raised': u'$4.6M',
#  u'twitter_username': u'LocuInc',
#  u'updated_at': u'Tue Aug 27 19:52:40 UTC 2013',
#  u'video_embeds': []}
# None

# %%
#connect to companies endpoint
import json
import httplib
import pprint as pp
import sqlite3

api_key = '52fppsddmrwecrwejqe6hm37'
main_url = 'api.crunchbase.com'
companies_entitylist_str = '/v/1/companies.js?'
company_entityinfo_str ='/v/1/company/'

def initiate_connection(url):
	return httplib.HTTPConnection(url)
	
def send_companies_query(conn, query, sql_connection):
    ex_fp = open('exceptions.txt', 'w')
    conn.request("GET", query)
    try:
        val = conn.getresponse().read().replace('][',',')
        response = json.loads(val)
        for company in response:
            try:
                sql_connection.execute('''INSERT INTO companies VALUES (?, ?, ?)''', (company['name'], company['permalink'],company['category_code']))
            except :
                ex_fp.write(json.dumps(response))
    except ValueError, e:
        ex_fp.write(val)
    ex_fp.close()
    sql_connection.commit()

def get_info_for_companies(connection):
    query=company_entityinfo_str+'locu.js?api_key='+api_key
    connection.request("GET",query)
    apple = connection.getresponse().read()
    print (pp.pprint(json.loads(apple)))

def companies():
	#output = 'simple_output.txt'
    cb_connection=initiate_connection(main_url)
    get_info_for_companies(cb_connection)
    #sql_connection = sqlite3.connect("companies.db")
    #sql_connection.cursor()
    #sql_connection.execute('''DROP TABLE IF EXISTS companies''')
    #sql_connection.execute('''CREATE TABLE companies (name text, permalink text, categorycode text)''')
    #sql_connection.commit()
    #query = "%sapi_key=%s" % (companies_entitylist_str, api_key)
    #send_companies_query (cb_connection, query, sql_connection)
    #sql_connection.close(cb_connection)

if __name__ == '__main__':
	companies()
